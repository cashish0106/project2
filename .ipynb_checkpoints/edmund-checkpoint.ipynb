# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
import pymongo
import time

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.carDB

db.vehicles.drop()
db.years.drop()

# Adding SUV manually to ensure script works everywhere
db.vehicles.insert_one(
    {
        'brand': ['acura','audi','bmw','infiniti','landrover','lexus','lincoln','mercedesbenz','porsche','volvo'],
        'model': ['mdx','q5','x5','qx60','range-rover','rx-350','mkx','m-class|gle-class','cayenne','xc90']
    }
)
###Skipping 2014 and 2015 for now
#db.years.insert_one(
#    { 'year':['2014','2015','2016','2017','2018']
#    }
#)

db.years.insert_one(
    { 'year':['2016','2017','2018']
    }
)

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=True)
#url = 'https://www.edmunds.com/cadillac/xt5/2017/cost-to-own/'
#browser.visit(url)
#html = browser.html
#soup = BeautifulSoup(html, 'html.parser')
#soup = BeautifulSoup(html, 'lxml')

# %%
def scrape(url,ss):
    browser.visit(url)
    time.sleep(ss)
    html = browser.html
    #soup = BeautifulSoup(html, 'html.parser')
    soup = BeautifulSoup(html, 'lxml')
    return soup

# %%
def make_it_num(strInput):
    if(strInput):
        return strInput.replace("$","").replace(",","").strip()
    else:
        return 0

# %%
def save_car_record(detail):
    if (len(detail) > 0):
        car_year=detail[0].strip()
        car_brand=detail[1].strip()
        car_model=detail[2].strip()
        car_true_cost_own=make_it_num(detail[3])
        car_cash_price=make_it_num(detail[4].strip())
        car_depreciation=[make_it_num(car_detail[i]) for i in range(6,12)]
        car_taxes=[make_it_num(car_detail[i]) for i in range(13,19)]
        car_financing=[make_it_num(car_detail[i]) for i in range(20,26)]
        car_fuel=[make_it_num(car_detail[i]) for i in range(27,33)]
        car_insurance=[make_it_num(car_detail[i]) for i in range(34,40)]
        car_maintenance=[make_it_num(car_detail[i]) for i in range(41,47)]
        car_repairs=[make_it_num(car_detail[i]) for i in range(48,54)]
        car_true_cost_5yr=[make_it_num(car_detail[i]) for i in range(55,61)]
        
        mongo_record={'year':car_year,
                       'brand':car_brand,
                       'model':car_model,
                       'owning_cost':car_true_cost_own,
                       'cash_price':car_cash_price,
                       'depreciation':car_depreciation,
                       'taxes':car_taxes,
                       'financing':car_financing,
                       'fuel':car_fuel,
                       'insurance':car_insurance,
                       'maintenance':car_maintenance,
                       'repairs':car_repairs,
                       'true_cost_5yr':car_true_cost_5yr
                     }
        #print(mongo_record)
        db[car_year].insert_one(mongo_record)
        return f"Record inserted successfully for {car_year} {car_brand} {car_model}"
         
        
    else:
        print("Nothing to save")

# %%
###################################### MAIN PROGRAM ########################################
########################   set below three variables to scrape data ########################
total_years=3
total_vehicles=10
sleep_seconds=15

#############################################################################################

years=db.years.find()
vehicles = db.vehicles.find()

##Output variable###
## This will contain complete record as list
## where 
### Index 0 - car year
### Index 1 - brand
### Index 2 - Model
### Index 3 - true cost to own
### Index 4 - total cash price
### Index5 onward - TCO details
car_detail=[] 

try:
    
    for i in range(total_years):
        c_year=years[0]['year'][i]

        for j in range(total_vehicles):
            car_detail=[]
            c_brand=vehicles[0]['brand'][j]
            c_model=vehicles[0]['model'][j]
            print(f"--------------------Checking for {c_year} {c_brand} {c_model}")
            if(c_brand =='mercedesbenz'):
                if(c_year =='2014' or c_year=='2015'):
                    c_model=c_model.split("|")[0]
                else:
                    c_model=c_model.split("|")[1]
                        # Output variable

            car_detail.append(c_year)
            car_detail.append(c_brand)
            car_detail.append(c_model)

            url=f'https://www.edmunds.com/{c_brand}/{c_model}/{c_year}/cost-to-own/'

            print(url)

            #Finding MSRP
            soup_output=scrape(url,sleep_seconds)
            msrp_results = soup_output.find("div", class_="grid-60").find_all('ul')
            for msrp_result in msrp_results:
                #print(msrp_result.find_all('li')[1].text.replace("$","").replace(",","")  )
                car_detail.append(msrp_result.find_all('li')[1].text)

            #finding TCO details
            tco_results = soup_output.find('ul',id="tco_detail_data").find_all('li')
            for i in range(8,len(tco_results),8):
                records = tco_results[i].find('ul').find_all('li')

                for record in records:
                    #print(record.text)
                    car_detail.append(record.text)
            print(save_car_record(car_detail))
            
except Exception as e:
    print(e)
    print(f"%%%%%%%%%%%%%%%%%%%%%%%%%Failed for {c_year} {c_brand} {c_model}%%%%%%%%%%%%%%%%%%%%%%%%%%%")
    print(url)
    print('###############################################################################################')
    pass
# Out:
# --------------------Checking for 2016 acura mdx
# https://www.edmunds.com/acura/mdx/2016/cost-to-own/
# Record inserted successfully for 2016 acura mdx
# --------------------Checking for 2016 audi q5
# https://www.edmunds.com/audi/q5/2016/cost-to-own/
# Record inserted successfully for 2016 audi q5
# --------------------Checking for 2016 bmw x5
# https://www.edmunds.com/bmw/x5/2016/cost-to-own/
# Record inserted successfully for 2016 bmw x5
# --------------------Checking for 2016 infiniti qx60
# https://www.edmunds.com/infiniti/qx60/2016/cost-to-own/
# Record inserted successfully for 2016 infiniti qx60
# --------------------Checking for 2016 landrover range-rover
# https://www.edmunds.com/landrover/range-rover/2016/cost-to-own/
# Record inserted successfully for 2016 landrover range-rover
# --------------------Checking for 2016 lexus rx-350
# https://www.edmunds.com/lexus/rx-350/2016/cost-to-own/
# Record inserted successfully for 2016 lexus rx-350
# --------------------Checking for 2016 lincoln mkx
# https://www.edmunds.com/lincoln/mkx/2016/cost-to-own/
# Record inserted successfully for 2016 lincoln mkx
# --------------------Checking for 2016 mercedesbenz m-class|gle-class
# https://www.edmunds.com/mercedesbenz/gle-class/2016/cost-to-own/
# Record inserted successfully for 2016 mercedesbenz gle-class
# --------------------Checking for 2016 porsche cayenne
# https://www.edmunds.com/porsche/cayenne/2016/cost-to-own/
# Record inserted successfully for 2016 porsche cayenne
# --------------------Checking for 2016 volvo xc90
# https://www.edmunds.com/volvo/xc90/2016/cost-to-own/
# Record inserted successfully for 2016 volvo xc90
# --------------------Checking for 2017 acura mdx
# https://www.edmunds.com/acura/mdx/2017/cost-to-own/
# Record inserted successfully for 2017 acura mdx
# --------------------Checking for 2017 audi q5
# https://www.edmunds.com/audi/q5/2017/cost-to-own/
# Record inserted successfully for 2017 audi q5
# --------------------Checking for 2017 bmw x5
# https://www.edmunds.com/bmw/x5/2017/cost-to-own/
# Record inserted successfully for 2017 bmw x5
# --------------------Checking for 2017 infiniti qx60
# https://www.edmunds.com/infiniti/qx60/2017/cost-to-own/
# Record inserted successfully for 2017 infiniti qx60
# --------------------Checking for 2017 landrover range-rover
# https://www.edmunds.com/landrover/range-rover/2017/cost-to-own/
# Record inserted successfully for 2017 landrover range-rover
# --------------------Checking for 2017 lexus rx-350
# https://www.edmunds.com/lexus/rx-350/2017/cost-to-own/
# Record inserted successfully for 2017 lexus rx-350
# --------------------Checking for 2017 lincoln mkx
# https://www.edmunds.com/lincoln/mkx/2017/cost-to-own/
# Record inserted successfully for 2017 lincoln mkx
# --------------------Checking for 2017 mercedesbenz m-class|gle-class
# https://www.edmunds.com/mercedesbenz/gle-class/2017/cost-to-own/
# Record inserted successfully for 2017 mercedesbenz gle-class
# --------------------Checking for 2017 porsche cayenne
# https://www.edmunds.com/porsche/cayenne/2017/cost-to-own/
# Record inserted successfully for 2017 porsche cayenne
# --------------------Checking for 2017 volvo xc90
# https://www.edmunds.com/volvo/xc90/2017/cost-to-own/
# Record inserted successfully for 2017 volvo xc90
# --------------------Checking for 2018 acura mdx
# https://www.edmunds.com/acura/mdx/2018/cost-to-own/
